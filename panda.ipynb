# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '3.0.0'

# %%
data = {
    'students' : ['Aryan','samyak','daksh','devansh','shrestha'],
    'subjects' : ["Python", "html","css","react","javaScript"],
    'marks' : [100,99,91,98,100]
}

# %%
data
# Out:
# {'students': ['Aryan', 'samyak', 'daksh', 'devansh', 'shrestha'],
#  'subjects': ['Python', 'html', 'css', 'react', 'javaScript'],
#  'marks': [100, 99, 91, 98, 100]}

# %%
df = pd.DataFrame(data,index=['one','two','three','four','five'])

# %%
df
# Out:
#        students    subjects  marks
# one       Aryan      Python    100
# two      samyak        html     99
# three     daksh         css     91
# four    devansh       react     98
# five   shrestha  javaScript    100
